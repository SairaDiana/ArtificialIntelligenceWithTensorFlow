# %% [markdown]
# # Importar paquetes

# %%
conda install -c conda-forge missingno
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.12
#   latest version: 4.8.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
conda update -n base -c defaults conda
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\saira\Anaconda3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     backports.functools_lru_cache-1.6.1|             py_0          11 KB
#     conda-4.8.1                |           py37_0         2.8 MB
#     future-0.18.2              |           py37_0         656 KB
#     ------------------------------------------------------------
#                                            Total:         3.5 MB
#
# The following packages will be UPDATED:
#
#   backports.functoo~                               1.5-py_2 --> 1.6.1-py_0
#   conda                                       4.7.12-py37_0 --> 4.8.1-py37_0
#   future                                      0.17.1-py37_0 --> 0.18.2-py37_0
#
#
#
# Downloading and Extracting Packages
#
# conda-4.8.1          | 2.8 MB    |            |   0%
# conda-4.8.1          | 2.8 MB    |            |   1%
# conda-4.8.1          | 2.8 MB    | 2          |   2%
# conda-4.8.1          | 2.8 MB    | 5          |   6%
# conda-4.8.1          | 2.8 MB    | 7          |   7%
# conda-4.8.1          | 2.8 MB    | 9          |  10%
# conda-4.8.1          | 2.8 MB    | #2         |  13%
# conda-4.8.1          | 2.8 MB    | ##3        |  23%
# conda-4.8.1          | 2.8 MB    | ##6        |  27%
# conda-4.8.1          | 2.8 MB    | ###        |  31%
# conda-4.8.1          | 2.8 MB    | ###4       |  34%
# conda-4.8.1          | 2.8 MB    | ####4      |  45%
# conda-4.8.1          | 2.8 MB    | ####9      |  50%
# conda-4.8.1          | 2.8 MB    | #####6     |  56%
# conda-4.8.1          | 2.8 MB    | ######     |  61%
# conda-4.8.1          | 2.8 MB    | ######4    |  64%
# conda-4.8.1          | 2.8 MB    | ######8    |  68%
# conda-4.8.1          | 2.8 MB    | #######1   |  72%
# conda-4.8.1          | 2.8 MB    | #######4   |  75%
# conda-4.8.1          | 2.8 MB    | #######8   |  78%
# conda-4.8.1          | 2.8 MB    | ########3  |  84%
# conda-4.8.1          | 2.8 MB    | ########7  |  87%
# conda-4.8.1          | 2.8 MB    | #########  |  90%
# conda-4.8.1          | 2.8 MB    | #########3 |  94%
# conda-4.8.1          | 2.8 MB    | #########7 |  97%
# conda-4.8.1          | 2.8 MB    | ########## | 100%
#
# backports.functools_ | 11 KB     |            |   0%
# backports.functools_ | 11 KB     | ########## | 100%
#
# future-0.18.2        | 656 KB    |            |   0%
# future-0.18.2        | 656 KB    | 7          |   7%
# future-0.18.2        | 656 KB    | ##1        |  22%
# future-0.18.2        | 656 KB    | ###6       |  37%
# future-0.18.2        | 656 KB    | #####1     |  51%
# future-0.18.2        | 656 KB    | ######1    |  61%
# future-0.18.2        | 656 KB    | ########5  |  85%
# future-0.18.2        | 656 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Cargamos todas las librerias necesarias

# %%
import pandas as pd
import missingno as msno
import numpy as np
# %matplotlib inline

# %% [markdown]
# # Cargamos la tabla en un dataframe

# %%
file = "C:/Users/saira/Documents/DIPLOMADO/MODULO IV/PRACTICAS/PRACTICA2/Dataset/vivienda.csv"

# %%
df = pd.read_csv(file)

# %%
df.head()
# Out:
#     folioviv tipo_viv condominio elevador  mat_pared  mat_techos mat_pisos  \
# 0  100008010        1                              8           9         3
# 1  100008034        1                              8           9         3
# 2  100008077        1                              8           9         3
# 3  100025016        1                              8           9         3
# 4  100025022        1                              8           9         3
#
#    ais_techos  ais_pared  ais_ventan  ...  tv_paga auto_pick  tot_hog  \
# 0           2          2           2  ...        2         1        1
# 1           1          2           2  ...        1         1        1
# 2           9          9           2  ...        1         1        1
# 3           1          2           2  ...        2         1        1
# 4           2          2           2  ...        1         1        1
#
#   ubica_geo   ageb  tam_loc  est_socio est_dis  upm factor
# 0  10010000  000-0        1          4       8    1    221
# 1  10010000  000-0        1          4       8    1    221
# 2  10010000  000-0        1          4       8    1    221
# 3  10010000  000-0        1          3       7    2    194
# 4  10010000  000-0        1          3       7    2    194
#
# [5 rows x 110 columns]

# %% [markdown]
# Copiamos el dataframe para trabajar sobre él sin alterar el origen de los datos

# %%
df_copy = df.copy()

# %% [markdown]
# Revisamos las dimensiones del problema

# %%
df_copy.shape
# Out:
# (56680, 110)

# %% [markdown]
# Revisamos el número de observaciones o filas

# %%
df_copy.shape[0]
# Out:
# 56680

# %% [markdown]
# Revisamos el número de variables o características o atributos

# %%
df_copy.shape[1]
# Out:
# 110

# %% [markdown]
# Revisamos las variables

# %%
df_copy.columns
# Out:
# Index(['folioviv', 'tipo_viv', 'condominio', 'elevador', 'mat_pared',
#        'mat_techos', 'mat_pisos', 'ais_techos', 'ais_pared', 'ais_ventan',
#        ...
#        'tv_paga', 'auto_pick', 'tot_hog', 'ubica_geo', 'ageb', 'tam_loc',
#        'est_socio', 'est_dis', 'upm', 'factor'],
#       dtype='object', length=110)

# %% [markdown]
# Enlistamos las columnas

# %%
list(df_copy.columns)
# Out:
# ['folioviv',
#  'tipo_viv',
#  'condominio',
#  'elevador',
#  'mat_pared',
#  'mat_techos',
#  'mat_pisos',
#  'ais_techos',
#  'ais_pared',
#  'ais_ventan',
#  'ais_otro',
#  'antiguedad',
#  'cocina',
#  'cocina_dor',
#  'cuart_dorm',
#  'num_cuarto',
#  'disp_agua',
#  'dotac_agua',
#  'excusado',
#  'uso_compar',
#  'sanit_agua',
#  'bano_comp',
#  'bano_excus',
#  'bano_regad',
#  'drenaje',
#  'disp_elect',
#  'anio_panel',
#  'panel_ne',
#  'pot_panel',
#  'potencia',
#  'focos_inca',
#  'focos_ahor',
#  'combustible',
#  'estufa_chi',
#  'eli_basura',
#  'lavadero',
#  'fregadero',
#  'regadera',
#  'rega_elect',
#  'tinaco_azo',
#  'cisterna',
#  'pileta',
#  'calent_sol',
#  'calent_gas',
#  'medidor_luz',
#  'bomba_agua',
#  'tanque_gas',
#  'aire_acond',
#  'calefacc',
#  'chimenea',
#  'repar_pard',
#  'repar_tech',
#  'repar_agua',
#  'repar_dren',
#  'repar_cabl',
#  'const_dorm',
#  'const_coci',
#  'const_bano',
#  'const_neg',
#  'comun1',
#  'comun2',
#  'comun3',
#  'comun4',
#  'comun5',
#  'comun6',
#  'comun7',
#  'comun8',
#  'comun9',
#  'estaciona',
#  'comun10',
#  'comun11',
#  'comun12',
#  'comun13',
#  'comun14',
#  'comun15',
#  'comun16',
#  'comun17',
#  'tenencia',
#  'pago_renta',
#  'anio_res',
#  'mes_res',
#  'familiar',
#  'tipo_adqui',
#  'financia_1',
#  'financia_2',
#  'financia_3',
#  'financia_4',
#  'financia_5',
#  'financia_6',
#  'financia_7',
#  'financia_8',
#  'num_dueno1',
#  'hog_dueno1',
#  'num_dueno2',
#  'hog_dueno2',
#  'escrituras',
#  'computador',
#  'tel_fijo',
#  'celular',
#  'internet',
#  'tv_paga',
#  'auto_pick',
#  'tot_hog',
#  'ubica_geo',
#  'ageb',
#  'tam_loc',
#  'est_socio',
#  'est_dis',
#  'upm',
#  'factor']

# %% [markdown]
# Seleccionamos una variable y revisamos sus valores

# %%
df_copy['tel_fijo'].value_counts()
# Out:
# 2    37355
# 1    19325
# Name: tel_fijo, dtype: int64

# %% [markdown]
# Seleccionamos una variable y revisamos los valores únicos

# %%
df_copy['tel_fijo'].unique()
# Out:
# array([1, 2], dtype=int64)

# %% [markdown]
# Revisamos todas las columnas y checamos sus valores únicos

# %%
l = []
bandera = np.NAN
for column in df_copy.columns:
    if df_copy[column].dtype == np.int64:
        bandera = 'entero'
    elif df_copy[column].dtype == np.float64:
        bandera = 'flotante'
    else:
        bandera = 'otro'
        
    try:
        df_copy[column] =df_copy[column].astype('int64')
    except:
        l.append(column)
        
    print('COLUMNA: ', column)
    print('TIPO: ', bandera)
    print('NUNIQUE: ', df_copy[column].nunique())
    print('UNIQUE: ', df_copy[column].unique())
    print('VALUE COUNTS ', df_copy[column].value_counts())
    print('\n')
# Out:
# COLUMNA:  folioviv
# TIPO:  entero
# NUNIQUE:  56680
# UNIQUE:  [ 100008010  100008034  100008077 ... 3260737208 3260737210 3260737211]
# VALUE COUNTS  1412184057    1
# 3060078007    1
# 2900807116    1
# 3202046090    1
# 3200448001    1
#              ..
# 1901026056    1
# 502425042     1
# 300437027     1
# 504127009     1
# 2701787136    1
# Name: folioviv, Length: 56680, dtype: int64
#
#
# COLUMNA:  tipo_viv
# TIPO:  otro
# NUNIQUE:  6
# UNIQUE:  ['1' '2' '3' '&' '4' '5']
# VALUE COUNTS  1    53650
# 2     2416
# 3      482
# &      114
# 4       12
# 5        6
# Name: tipo_viv, dtype: int64
#
#
# COLUMNA:  condominio
# TIPO:  otro
# NUNIQUE:  19
# UNIQUE:  [' ' '04' '02' '03' '05' '07' '22' '06' '08' '12' '09' '13' '10' '11' '16'
#  '15' '14' '24' '23']
# VALUE COUNTS        54150
# 02     1065
# 03      594
# 04      494
# 05      268
# 06       53
# 07       26
# 12        7
# 08        5
# 09        4
# 10        4
# 11        3
# 23        1
# 22        1
# 24        1
# 14        1
# 16        1
# 15        1
# 13        1
# Name: condominio, dtype: int64
#
#
# COLUMNA:  elevador
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  [' ' '2' '1']
# VALUE COUNTS       54150
# 2     2424
# 1      106
# Name: elevador, dtype: int64
#
#
# COLUMNA:  mat_pared
# TIPO:  entero
# NUNIQUE:  8
# UNIQUE:  [8 7 1 3 6 2 5 4]
# VALUE COUNTS  8    50149
# 7     3769
# 6     2051
# 3      293
# 5      189
# 4      122
# 1       55
# 2       52
# Name: mat_pared, dtype: int64
#
#
# COLUMNA:  mat_techos
# TIPO:  entero
# NUNIQUE:  9
# UNIQUE:  [9 3 8 4 7 1 6 5 2]
# VALUE COUNTS  9    42010
# 3     7851
# 4     3083
# 6     1534
# 8      850
# 7      620
# 2      424
# 5      264
# 1       44
# Name: mat_techos, dtype: int64
#
#
# COLUMNA:  mat_pisos
# TIPO:  otro
# NUNIQUE:  7
# UNIQUE:  [3 2 1 '3' '2' '1' '&']
# VALUE COUNTS  3    23901
# 2    23667
# 2     4330
# 3     3593
# 1      920
# 1      267
# &        2
# Name: mat_pisos, dtype: int64
#
#
# COLUMNA:  ais_techos
# TIPO:  entero
# NUNIQUE:  3
# UNIQUE:  [2 1 9]
# VALUE COUNTS  2    53163
# 1     2869
# 9      648
# Name: ais_techos, dtype: int64
#
#
# COLUMNA:  ais_pared
# TIPO:  entero
# NUNIQUE:  3
# UNIQUE:  [2 9 1]
# VALUE COUNTS  2    55305
# 1      737
# 9      638
# Name: ais_pared, dtype: int64
#
#
# COLUMNA:  ais_ventan
# TIPO:  entero
# NUNIQUE:  3
# UNIQUE:  [2 9 1]
# VALUE COUNTS  2    55748
# 9      561
# 1      371
# Name: ais_ventan, dtype: int64
#
#
# COLUMNA:  ais_otro
# TIPO:  entero
# NUNIQUE:  3
# UNIQUE:  [2 9 1]
# VALUE COUNTS  2    56020
# 9      590
# 1       70
# Name: ais_otro, dtype: int64
#
#
# COLUMNA:  antiguedad
# TIPO:  otro
# NUNIQUE:  97
# UNIQUE:  [' ' '42' '10' '43' '40' '22' '25' '30' '20' '15' '50' '46' '16' '65' '48'
#  '60' '9' '45' '12' '35' '4' '38' '80' '90' '31' '57' '99' '70' '36' '24'
#  '29' '37' '17' '14' '3' '39' '5' '32' '28' '18' '11' '7' '47' '26' '33'
#  '0' '2' '8' '55' '1' '27' '34' '44' '6' '23' '41' '21' '19' '13' '66'
#  '78' '88' '85' '53' '64' '59' '56' '62' '52' '67' '54' '58' '93' '63'
#  '72' '49' '74' '75' '86' '51' '71' '68' '61' '79' '77' '95' '87' '96'
#  '82' '76' '98' '69' '73' '84' '97' '89' '81']
# VALUE COUNTS        14165
# 20     3773
# 10     3387
# 30     3327
# 15     3052
#       ...
# 93        1
# 96        1
# 86        1
# 95        1
# 84        1
# Name: antiguedad, Length: 97, dtype: int64
#
#
# COLUMNA:  cocina
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 2]
# VALUE COUNTS  1    53256
# 2     3424
# Name: cocina, dtype: int64
#
#
# COLUMNA:  cocina_dor
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  ['2' ' ' '1']
# VALUE COUNTS  2    49279
# 1     3977
#       3424
# Name: cocina_dor, dtype: int64
#
#
# COLUMNA:  cuart_dorm
# TIPO:  entero
# NUNIQUE:  12
# UNIQUE:  [ 4  2  3  6  7  1  8  5  9 11 10 15]
# VALUE COUNTS  2     23460
# 1     17393
# 3     12212
# 4      2829
# 5       586
# 6       149
# 7        31
# 8        11
# 9         5
# 11        2
# 15        1
# 10        1
# Name: cuart_dorm, dtype: int64
#
#
# COLUMNA:  num_cuarto
# TIPO:  entero
# NUNIQUE:  18
# UNIQUE:  [ 7  5  9  4  6  8 10  3 12  1  2 11 13 16 15 14 17 19]
# VALUE COUNTS  4     15058
# 3     13206
# 5      9816
# 2      7352
# 6      4632
# 1      3196
# 7      1927
# 8       855
# 9       320
# 10      190
# 11       62
# 12       44
# 13       10
# 14        4
# 15        4
# 16        2
# 17        1
# 19        1
# Name: num_cuarto, dtype: int64
#
#
# COLUMNA:  disp_agua
# TIPO:  entero
# NUNIQUE:  6
# UNIQUE:  [1 2 4 5 6 3]
# VALUE COUNTS  1    41805
# 2    11347
# 6     1989
# 4      723
# 5      719
# 3       97
# Name: disp_agua, dtype: int64
#
#
# COLUMNA:  dotac_agua
# TIPO:  otro
# NUNIQUE:  6
# UNIQUE:  ['1' '2' '3' ' ' '4' '5']
# VALUE COUNTS  1    39500
# 2     7623
#       3528
# 3     2629
# 4     1858
# 5     1542
# Name: dotac_agua, dtype: int64
#
#
# COLUMNA:  excusado
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 2]
# VALUE COUNTS  1    54866
# 2     1814
# Name: excusado, dtype: int64
#
#
# COLUMNA:  uso_compar
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  ['2' '1' ' ']
# VALUE COUNTS  2    52483
# 1     2383
#       1814
# Name: uso_compar, dtype: int64
#
#
# COLUMNA:  sanit_agua
# TIPO:  otro
# NUNIQUE:  4
# UNIQUE:  ['1' '2' ' ' '3']
# VALUE COUNTS  1    39678
# 2    12883
# 3     2305
#       1814
# Name: sanit_agua, dtype: int64
#
#
# COLUMNA:  bano_comp
# TIPO:  otro
# NUNIQUE:  10
# UNIQUE:  ['2' '3' '1' '0' '4' ' ' '5' '6' '7' '9']
# VALUE COUNTS  1    30688
# 0    14581
# 2     7803
#       1814
# 3     1407
# 4      278
# 5       73
# 6       26
# 7        9
# 9        1
# Name: bano_comp, dtype: int64
#
#
# COLUMNA:  bano_excus
# TIPO:  otro
# NUNIQUE:  9
# UNIQUE:  ['0' '1' '3' '2' ' ' '9' '4' '5' '6']
# VALUE COUNTS  0    33894
# 1    19830
#       1814
# 2     1009
# 3       78
# 9       44
# 5        6
# 4        4
# 6        1
# Name: bano_excus, dtype: int64
#
#
# COLUMNA:  bano_regad
# TIPO:  otro
# NUNIQUE:  8
# UNIQUE:  ['0' '1' ' ' '2' '9' '6' '5' '3']
# VALUE COUNTS  0    53230
#       1814
# 1     1553
# 9       49
# 2       26
# 3        4
# 5        3
# 6        1
# Name: bano_regad, dtype: int64
#
#
# COLUMNA:  drenaje
# TIPO:  entero
# NUNIQUE:  5
# UNIQUE:  [1 2 5 3 4]
# VALUE COUNTS  1    41006
# 2    12033
# 5     3067
# 3      366
# 4      208
# Name: drenaje, dtype: int64
#
#
# COLUMNA:  disp_elect
# TIPO:  entero
# NUNIQUE:  5
# UNIQUE:  [1 5 2 4 3]
# VALUE COUNTS  1    56341
# 5      252
# 3       53
# 4       21
# 2       13
# Name: disp_elect, dtype: int64
#
#
# COLUMNA:  anio_panel
# TIPO:  otro
# NUNIQUE:  14
# UNIQUE:  [' ' '2012' '2015' '2016' '2009' '2014' '2002' '2001' '2011' '2010' '2005'
#  '2013' '2007' '2017']
# VALUE COUNTS          56636
# 2015        8
# 2014        8
# 2012        7
# 2016        7
# 2011        4
# 2013        2
# 2010        2
# 2017        1
# 2009        1
# 2005        1
# 2001        1
# 2002        1
# 2007        1
# Name: anio_panel, dtype: int64
#
#
# COLUMNA:  panel_ne
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  [' ' '9']
# VALUE COUNTS       56671
# 9        9
# Name: panel_ne, dtype: int64
#
#
# COLUMNA:  pot_panel
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  [' ' '1' '2']
# VALUE COUNTS       56627
# 2       37
# 1       16
# Name: pot_panel, dtype: int64
#
#
# COLUMNA:  potencia
# TIPO:  otro
# NUNIQUE:  8
# UNIQUE:  [' ' '210' '100' '12' '600' '110' '-1' '2']
# VALUE COUNTS         56664
# 110        6
# -1         4
# 100        2
# 600        1
# 2          1
# 12         1
# 210        1
# Name: potencia, dtype: int64
#
#
# COLUMNA:  focos_inca
# TIPO:  otro
# NUNIQUE:  40
# UNIQUE:  ['0' '13' '2' '6' '1' '3' '10' '9' '8' '4' '7' '5' '12' '15' '14' '17'
#  '11' ' ' '21' '20' '18' '25' '30' '35' '19' '16' '29' '27' '40' '70' '90'
#  '33' '37' '24' '26' '22' '91' '32' '23' '36']
# VALUE COUNTS  0     35514
# 2      4963
# 1      4867
# 3      3768
# 4      2594
# 5      1737
# 6      1162
# 7       596
# 8       425
#         252
# 10      225
# 9       220
# 12       79
# 11       66
# 15       54
# 13       31
# 14       31
# 20       22
# 17       13
# 16       11
# 25        9
# 18        7
# 30        5
# 22        4
# 19        3
# 40        3
# 70        2
# 26        2
# 29        2
# 24        2
# 32        2
# 90        1
# 35        1
# 37        1
# 21        1
# 33        1
# 27        1
# 36        1
# 91        1
# 23        1
# Name: focos_inca, dtype: int64
#
#
# COLUMNA:  focos_ahor
# TIPO:  otro
# NUNIQUE:  69
# UNIQUE:  ['6' '20' '10' '8' '2' '7' '5' '14' '15' '9' '40' '17' '0' '4' '3' '35'
#  '32' '11' '16' '13' '12' '50' '1' '24' '18' '26' '28' '22' '19' '25' '70'
#  '21' '30' '60' '27' '37' '29' '23' ' ' '43' '38' '34' '44' '36' '99' '42'
#  '31' '48' '39' '51' '65' '80' '54' '45' '47' '55' '63' '41' '75' '49'
#  '98' '52' '95' '90' '76' '56' '33' '64' '46']
# VALUE COUNTS  4     6216
# 0     5975
# 5     5930
# 6     5800
# 3     5695
#       ...
# 51       1
# 98       1
# 76       1
# 48       1
# 75       1
# Name: focos_ahor, Length: 69, dtype: int64
#
#
# COLUMNA:  combustible
# TIPO:  entero
# NUNIQUE:  6
# UNIQUE:  [3 4 5 6 2 1]
# VALUE COUNTS  3    44166
# 1     8073
# 4     2939
# 5      718
# 6      611
# 2      173
# Name: combustible, dtype: int64
#
#
# COLUMNA:  estufa_chi
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  [' ' '2' '1']
# VALUE COUNTS       48434
# 2     6368
# 1     1878
# Name: estufa_chi, dtype: int64
#
#
# COLUMNA:  eli_basura
# TIPO:  entero
# NUNIQUE:  6
# UNIQUE:  [2 1 3 5 6 4]
# VALUE COUNTS  1    45638
# 3     6484
# 2     3374
# 5      703
# 6      307
# 4      174
# Name: eli_basura, dtype: int64
#
#
# COLUMNA:  lavadero
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 2]
# VALUE COUNTS  1    47740
# 2     8940
# Name: lavadero, dtype: int64
#
#
# COLUMNA:  fregadero
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 2]
# VALUE COUNTS  1    35033
# 2    21647
# Name: fregadero, dtype: int64
#
#
# COLUMNA:  regadera
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 2]
# VALUE COUNTS  1    41159
# 2    15521
# Name: regadera, dtype: int64
#
#
# COLUMNA:  rega_elect
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  2    54710
# 1     1970
# Name: rega_elect, dtype: int64
#
#
# COLUMNA:  tinaco_azo
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 2]
# VALUE COUNTS  1    31983
# 2    24697
# Name: tinaco_azo, dtype: int64
#
#
# COLUMNA:  cisterna
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 2]
# VALUE COUNTS  2    45549
# 1    11131
# Name: cisterna, dtype: int64
#
#
# COLUMNA:  pileta
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  2    34699
# 1    21981
# Name: pileta, dtype: int64
#
#
# COLUMNA:  calent_sol
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 2]
# VALUE COUNTS  2    53482
# 1     3198
# Name: calent_sol, dtype: int64
#
#
# COLUMNA:  calent_gas
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 2]
# VALUE COUNTS  2    33894
# 1    22786
# Name: calent_gas, dtype: int64
#
#
# COLUMNA:  medidor_luz
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 2]
# VALUE COUNTS  1    53313
# 2     3367
# Name: medidor_luz, dtype: int64
#
#
# COLUMNA:  bomba_agua
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 2]
# VALUE COUNTS  2    42787
# 1    13893
# Name: bomba_agua, dtype: int64
#
#
# COLUMNA:  tanque_gas
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  2    51205
# 1     5475
# Name: tanque_gas, dtype: int64
#
#
# COLUMNA:  aire_acond
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  2    45363
# 1    11317
# Name: aire_acond, dtype: int64
#
#
# COLUMNA:  calefacc
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  2    55359
# 1     1321
# Name: calefacc, dtype: int64
#
#
# COLUMNA:  chimenea
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  2    55176
# 1     1504
# Name: chimenea, dtype: int64
#
#
# COLUMNA:  repar_pard
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  2    30763
# 1    25917
# Name: repar_pard, dtype: int64
#
#
# COLUMNA:  repar_tech
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  2    31228
# 1    25452
# Name: repar_tech, dtype: int64
#
#
# COLUMNA:  repar_agua
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  2    46696
# 1     9984
# Name: repar_agua, dtype: int64
#
#
# COLUMNA:  repar_dren
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  2    48803
# 1     7877
# Name: repar_dren, dtype: int64
#
#
# COLUMNA:  repar_cabl
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  2    44628
# 1    12052
# Name: repar_cabl, dtype: int64
#
#
# COLUMNA:  const_dorm
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  2    32085
# 1    24595
# Name: const_dorm, dtype: int64
#
#
# COLUMNA:  const_coci
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  2    39901
# 1    16779
# Name: const_coci, dtype: int64
#
#
# COLUMNA:  const_bano
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  2    36022
# 1    20658
# Name: const_bano, dtype: int64
#
#
# COLUMNA:  const_neg
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  2    42839
# 1    13841
# Name: const_neg, dtype: int64
#
#
# COLUMNA:  comun1
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 2]
# VALUE COUNTS  1    38194
# 2    18486
# Name: comun1, dtype: int64
#
#
# COLUMNA:  comun2
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 2]
# VALUE COUNTS  2    36115
# 1    20565
# Name: comun2, dtype: int64
#
#
# COLUMNA:  comun3
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 2]
# VALUE COUNTS  1    46973
# 2     9707
# Name: comun3, dtype: int64
#
#
# COLUMNA:  comun4
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 2]
# VALUE COUNTS  2    48675
# 1     8005
# Name: comun4, dtype: int64
#
#
# COLUMNA:  comun5
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  2    53887
# 1     2793
# Name: comun5, dtype: int64
#
#
# COLUMNA:  comun6
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 2]
# VALUE COUNTS  2    54604
# 1     2076
# Name: comun6, dtype: int64
#
#
# COLUMNA:  comun7
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  2    56215
# 1      465
# Name: comun7, dtype: int64
#
#
# COLUMNA:  comun8
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  2    56220
# 1      460
# Name: comun8, dtype: int64
#
#
# COLUMNA:  comun9
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 2]
# VALUE COUNTS  2    32334
# 1    24346
# Name: comun9, dtype: int64
#
#
# COLUMNA:  estaciona
# TIPO:  otro
# NUNIQUE:  11
# UNIQUE:  ['1' '3' ' ' '2' '8' '4' '10' '6' '5' '7' '9']
# VALUE COUNTS        32334
# 1     15704
# 2      6446
# 3      1295
# 4       552
# 5       180
# 6        93
# 10       32
# 8        28
# 7        14
# 9         2
# Name: estaciona, dtype: int64
#
#
# COLUMNA:  comun10
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  2    53927
# 1     2753
# Name: comun10, dtype: int64
#
#
# COLUMNA:  comun11
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  [' ' '2' '1']
# VALUE COUNTS       53927
# 2     2404
# 1      349
# Name: comun11, dtype: int64
#
#
# COLUMNA:  comun12
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  [' ' '2' '1']
# VALUE COUNTS       53927
# 2     2226
# 1      527
# Name: comun12, dtype: int64
#
#
# COLUMNA:  comun13
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  [' ' '2' '1']
# VALUE COUNTS       53927
# 2     2463
# 1      290
# Name: comun13, dtype: int64
#
#
# COLUMNA:  comun14
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  [' ' '2' '1']
# VALUE COUNTS       53927
# 1     1408
# 2     1345
# Name: comun14, dtype: int64
#
#
# COLUMNA:  comun15
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  [' ' '2' '1']
# VALUE COUNTS       53927
# 2     1418
# 1     1335
# Name: comun15, dtype: int64
#
#
# COLUMNA:  comun16
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  [' ' '2' '1']
# VALUE COUNTS       53927
# 2     2532
# 1      221
# Name: comun16, dtype: int64
#
#
# COLUMNA:  comun17
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  [' ' '1' '2']
# VALUE COUNTS       53927
# 2     1927
# 1      826
# Name: comun17, dtype: int64
#
#
# COLUMNA:  tenencia
# TIPO:  entero
# NUNIQUE:  6
# UNIQUE:  [4 1 3 2 5 6]
# VALUE COUNTS  4    30361
# 2     9880
# 1     7976
# 3     5820
# 5     1889
# 6      754
# Name: tenencia, dtype: int64
#
#
# COLUMNA:  pago_renta
# TIPO:  otro
# NUNIQUE:  181
# UNIQUE:  [' ' '4000' '2000' '2500' '5000' '1800' '1500' '2300' '1000' '1100' '3500'
#  '1300' '800' '3000' '2800' '1700' '2600' '2200' '1050' '900' '750' '400'
#  '7000' '5500' '5600' '4500' '700' '1400' '1600' '4700' '3300' '1200'
#  '350' '200' '500' '6000' '3800' '250' '1900' '2400' '600' '999' '2700'
#  '950' '4100' '5200' '1750' '6500' '1250' '5300' '3200' '300' '2100'
#  '3250' '1150' '2900' '45000' '6800' '9000' '7200' '1350' '10000' '5250'
#  '3400' '10800' '11000' '5400' '8000' '2250' '4350' '1450' '2850' '850'
#  '9500' '6125' '550' '9999' '15000' '450' '12000' '40000' '2750' '7500'
#  '4200' '440' '3900' '3252' '980' '460' '480' '1950' '8500' '670' '1650'
#  '650' '150' '1020' '680' '3100' '17000' '6400' '25000' '6200' '3700'
#  '4800' '18000' '30000' '35000' '22000' '5700' '3600' '11500' '7800'
#  '10200' '7100' '13000' '14000' '6150' '5130' '20000' '8800' '21000'
#  '24000' '38000' '36000' '31000' '1880' '3050' '8400' '925' '1040' '15500'
#  '100' '9200' '2550' '3150' '1550' '4300' '6600' '3850' '7600' '8750'
#  '16000' '6700' '50' '470' '8300' '1060' '1920' '1' '6300' '5150' '13500'
#  '5100' '2650' '1850' '5900' '3650' '13200' '4150' '8250' '10500' '14500'
#  '5800' '4250' '430' '6250' '1085' '4400' '4600' '1509' '920' '7400' '675'
#  '830' '41' '555' '240' '880' '970' '710']
# VALUE COUNTS           48704
# 1000       892
# 1500       847
# 2000       645
# 1200       572
#          ...
# 675          1
# 41           1
# 13500        1
# 4250         1
# 8800         1
# Name: pago_renta, Length: 181, dtype: int64
#
#
# COLUMNA:  anio_res
# TIPO:  otro
# NUNIQUE:  44
# UNIQUE:  [' ' '0' '10' '2' '8' '6' '11' '1' '3' '12' '32' '7' '30' '5' '19' '4'
#  '23' '9' '14' '13' '15' '22' '21' '60' '18' '28' '16' '17' '20' '25' '40'
#  '50' '35' '29' '44' '47' '27' '39' '26' '36' '45' '61' '42' '37']
# VALUE COUNTS        48704
# 0      2488
# 1      1477
# 2      1106
# 3       755
# 4       484
# 5       459
# 6       231
# 7       185
# 10      177
# 8       160
# 9        78
# 15       58
# 12       56
# 11       39
# 20       34
# 14       23
# 13       21
# 18       20
# 16       19
# 17       19
# 30       15
# 25       10
# 19        7
# 23        6
# 40        6
# 21        6
# 22        5
# 32        5
# 28        4
# 47        3
# 35        2
# 29        2
# 60        2
# 36        2
# 26        2
# 50        2
# 27        2
# 37        1
# 44        1
# 45        1
# 39        1
# 61        1
# 42        1
# Name: anio_res, dtype: int64
#
#
# COLUMNA:  mes_res
# TIPO:  otro
# NUNIQUE:  13
# UNIQUE:  [' ' '6' '0' '7' '3' '11' '1' '5' '2' '8' '9' '10' '4']
# VALUE COUNTS        48704
# 0      3649
# 6       988
# 2       504
# 1       501
# 3       469
# 4       379
# 5       352
# 8       340
# 7       216
# 10      202
# 9       201
# 11      175
# Name: mes_res, dtype: int64
#
#
# COLUMNA:  familiar
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  [' ' '1' '2']
# VALUE COUNTS       48704
# 2     6909
# 1     1067
# Name: familiar, dtype: int64
#
#
# COLUMNA:  tipo_adqui
# TIPO:  otro
# NUNIQUE:  5
# UNIQUE:  ['1' '4' ' ' '2' '3']
# VALUE COUNTS       20499
# 2    14086
# 1    11898
# 3     6947
# 4     3250
# Name: tipo_adqui, dtype: int64
#
#
# COLUMNA:  financia_1
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  [' ' '1']
# VALUE COUNTS       32972
# 1    23708
# Name: financia_1, dtype: int64
#
#
# COLUMNA:  financia_2
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  [' ' '2']
# VALUE COUNTS       56438
# 2      242
# Name: financia_2, dtype: int64
#
#
# COLUMNA:  financia_3
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  ['3' ' ']
# VALUE COUNTS       49748
# 3     6932
# Name: financia_3, dtype: int64
#
#
# COLUMNA:  financia_4
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  [' ' '4']
# VALUE COUNTS       55089
# 4     1591
# Name: financia_4, dtype: int64
#
#
# COLUMNA:  financia_5
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  [' ' '5']
# VALUE COUNTS       56490
# 5      190
# Name: financia_5, dtype: int64
#
#
# COLUMNA:  financia_6
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  [' ' '6']
# VALUE COUNTS       56321
# 6      359
# Name: financia_6, dtype: int64
#
#
# COLUMNA:  financia_7
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  [' ' '7']
# VALUE COUNTS       55794
# 7      886
# Name: financia_7, dtype: int64
#
#
# COLUMNA:  financia_8
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  [' ' '8']
# VALUE COUNTS       55236
# 8     1444
# Name: financia_8, dtype: int64
#
#
# COLUMNA:  num_dueno1
# TIPO:  otro
# NUNIQUE:  12
# UNIQUE:  ['01' ' ' '02' '03' '05' '04' '07' '11' '06' '09' '08' '10']
# VALUE COUNTS  01    29146
#       20495
# 02     6205
# 03      574
# 04      121
# 05       73
# 06       35
# 07       13
# 08        9
# 09        5
# 10        3
# 11        1
# Name: num_dueno1, dtype: int64
#
#
# COLUMNA:  hog_dueno1
# TIPO:  otro
# NUNIQUE:  5
# UNIQUE:  ['1' ' ' '2' '3' '5']
# VALUE COUNTS  1    36063
#      20495
# 2      109
# 3       12
# 5        1
# Name: hog_dueno1, dtype: int64
#
#
# COLUMNA:  num_dueno2
# TIPO:  otro
# NUNIQUE:  9
# UNIQUE:  [' ' '02' '03' '01' '04' '06' '07' '14' '05']
# VALUE COUNTS        52798
# 02     3467
# 01      243
# 03      102
# 04       52
# 05        8
# 07        5
# 06        4
# 14        1
# Name: num_dueno2, dtype: int64
#
#
# COLUMNA:  hog_dueno2
# TIPO:  otro
# NUNIQUE:  4
# UNIQUE:  [' ' '1' '2' '3']
# VALUE COUNTS       52798
# 1     3876
# 2        5
# 3        1
# Name: hog_dueno2, dtype: int64
#
#
# COLUMNA:  escrituras
# TIPO:  otro
# NUNIQUE:  5
# UNIQUE:  ['1' ' ' '3' '9' '2']
# VALUE COUNTS  1    27323
#      20499
# 3     7519
# 2     1052
# 9      287
# Name: escrituras, dtype: int64
#
#
# COLUMNA:  computador
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  2    36812
# 1    19868
# Name: computador, dtype: int64
#
#
# COLUMNA:  tel_fijo
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 2]
# VALUE COUNTS  2    37355
# 1    19325
# Name: tel_fijo, dtype: int64
#
#
# COLUMNA:  celular
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 2]
# VALUE COUNTS  1    49755
# 2     6925
# Name: celular, dtype: int64
#
#
# COLUMNA:  internet
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 2]
# VALUE COUNTS  2    30894
# 1    25786
# Name: internet, dtype: int64
#
#
# COLUMNA:  tv_paga
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  1    29292
# 2    27388
# Name: tv_paga, dtype: int64
#
#
# COLUMNA:  auto_pick
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 2]
# VALUE COUNTS  2    31356
# 1    25324
# Name: auto_pick, dtype: int64
#
#
# COLUMNA:  tot_hog
# TIPO:  entero
# NUNIQUE:  5
# UNIQUE:  [1 2 3 4 5]
# VALUE COUNTS  1    55972
# 2      599
# 3       90
# 4       16
# 5        3
# Name: tot_hog, dtype: int64
#
#
# COLUMNA:  ubica_geo
# TIPO:  entero
# NUNIQUE:  926
# UNIQUE:  [ 10010000  10030000  10050000  10060000  10070000  10040000  10090000
#   10100000  10110000  10020000  20010000  20020000  20040000  20030000
#   20050000  30030000  30010000  30080000  30020000  30090000  40020000
#   40030000  40040000  40090000  40010000  40050000  40060000  40080000
#   40100000  40110000  50020000  50180000  50250000  50300000  50350000
#   50030000  50090000  50100000  50170000  50200000  50240000  50270000
#   50280000  50310000  50330000  50220000  50230000  50040000  50360000
#   60020000  60070000  60100000  60010000  60090000  60030000  60040000
#   60060000  60080000  70780000  70890000  71010000  70170000  70190000
#   70270000  70400000  70520000  70590000  70610000  70650000  70690000
#   70750000  70860000  71080000  70010000  70130000  70310000  70320000
#   70370000  70420000  70680000  70790000  70810000  70830000  70990000
#   71020000  71050000  71060000  70020000  70200000  70930000  70960000
#   70970000  71120000  70030000  70040000  70090000  70150000  70210000
#   70230000  70300000  70350000  70470000  70490000  70670000  70720000
#   70740000  70760000  70770000  70800000  70920000  70940000  71130000
#   70530000  80170000  80190000  80210000  80320000  80370000  80110000
#   80360000  80500000  80520000  80030000  80040000  80100000  80310000
#   80400000  80450000  80070000  80200000  80350000  80480000  80540000
#   80220000  90020000  90030000  90040000  90050000  90060000  90070000
#   90080000  90100000  90110000  90120000  90130000  90140000  90150000
#   90160000  90170000  90090000 100050000 100070000 100120000 100320000
#  100380000 100010000 100040000 100150000 100170000 100200000 100220000
#  100350000 100360000 100080000 100160000 100280000 100030000 100060000
#  100090000 100100000 100210000 100310000 110070000 110170000 110200000
#  110270000 110010000 110020000 110030000 110090000 110140000 110150000
#  110230000 110250000 110280000 110300000 110310000 110320000 110330000
#  110370000 110420000 110460000 110080000 110180000 110050000 110110000
#  110290000 110120000 110190000 110350000 110430000 120010000 120290000
#  120350000 120070000 120110000 120120000 120340000 120460000 120480000
#  120550000 120610000 120030000 120040000 120200000 120230000 120300000
#  120360000 120380000 120490000 120520000 120530000 120660000 120680000
#  120140000 120210000 120560000 120570000 120730000 120100000 120220000
#  120400000 120450000 120620000 120640000 120720000 120740000 120750000
#  120760000 120710000 130480000 130770000 130030000 130160000 130280000
#  130300000 130410000 130500000 130560000 130610000 130630000 130690000
#  130760000 130020000 130130000 130210000 130320000 130460000 130510000
#  130570000 130580000 130590000 130670000 130700000 130740000 130750000
#  130820000 130170000 130290000 130640000 130730000 130010000 130150000
#  130200000 130220000 130240000 130250000 130260000 130270000 130370000
#  130400000 130490000 130600000 130620000 130680000 130810000 140390000
#  140670000 140980000 141010000 141200000 140060000 140080000 140150000
#  140230000 140370000 140500000 140630000 140700000 140830000 140970000
#  141080000 141210000 140210000 140300000 140360000 141000000 141050000
#  141140000 141250000 140660000 140180000 140290000 140350000 140850000
#  140900000 141240000 140120000 150020000 150130000 150200000 150240000
#  150250000 150290000 150310000 150330000 150370000 150390000 150570000
#  150580000 150600000 150810000 150990000 151040000 151060000 151090000
#  151210000 151220000 150050000 150090000 150230000 150300000 150430000
#  150440000 150540000 150700000 150760000 150910000 150920000 151080000
#  151200000 150220000 150280000 150420000 150510000 150530000 150670000
#  150870000 150950000 151000000 151010000 150070000 150860000 150030000
#  150480000 150520000 150630000 151100000 151240000 160530000 161020000
#  161080000 160090000 160340000 160380000 160430000 160500000 160520000
#  160690000 160710000 160750000 160760000 161070000 161120000 160150000
#  160190000 160330000 160360000 160370000 160470000 160490000 160560000
#  160820000 160840000 160860000 160880000 160940000 160990000 161030000
#  161100000 161110000 161130000 160170000 160200000 160810000 161010000
#  160030000 160140000 160260000 160280000 160310000 160670000 160730000
#  160870000 160930000 160970000 160070000 161040000 170060000 170070000
#  170110000 170030000 170080000 170120000 170170000 170180000 170250000
#  170280000 170290000 170310000 170040000 170090000 170130000 170150000
#  170160000 170190000 170200000 170210000 170220000 170300000 170330000
#  170140000 170050000 180170000 180010000 180040000 180060000 180080000
#  180150000 180180000 180200000 180070000 180110000 180120000 180140000
#  180160000 180090000 180100000 180190000 190060000 190190000 190210000
#  190260000 190310000 190390000 190460000 190480000 190040000 190050000
#  190180000 190330000 190380000 190470000 190490000 190100000 190250000
#  190320000 190030000 190360000 190410000 200670000 201840000 200390000
#  200430000 200590000 200790000 201070000 203850000 203900000 203970000
#  203990000 204130000 204820000 205150000 200050000 200300000 200520000
#  200750000 200830000 200870000 201150000 201240000 201410000 201500000
#  201530000 201570000 202270000 202480000 202930000 203240000 203500000
#  203670000 203980000 204180000 204720000 205250000 205510000 205530000
#  205570000 201340000 205260000 200190000 200230000 200400000 200440000
#  200580000 200720000 200850000 201670000 201850000 201900000 202010000
#  202070000 202170000 202250000 203090000 203100000 203440000 204060000
#  204390000 204460000 204660000 205000000 205230000 200340000 202370000
#  202600000 203300000 203490000 203560000 203870000 204930000 205060000
#  211140000 211560000 210150000 210190000 210410000 210450000 210530000
#  210740000 211190000 211320000 211400000 211540000 211740000 211970000
#  210140000 210260000 210340000 210480000 210510000 210630000 210650000
#  210690000 210750000 210850000 210900000 211370000 211770000 211860000
#  211990000 212050000 210720000 211150000 211700000 210060000 210160000
#  210360000 210710000 210790000 210860000 211060000 211110000 211130000
#  211290000 211410000 211570000 211720000 211920000 212130000 211260000
#  220140000 220160000 220060000 220170000 220010000 220050000 220070000
#  220110000 220120000 220080000 220030000 220040000 220090000 220100000
#  220150000 230040000 230050000 230080000 230010000 230020000 230090000
#  230030000 230100000 230060000 230070000 240130000 240280000 240350000
#  240110000 240200000 240240000 240370000 240400000 240010000 240150000
#  240270000 240360000 240390000 240490000 240500000 240530000 240100000
#  240520000 240030000 240060000 240140000 240170000 240210000 240220000
#  240310000 240320000 240420000 240540000 250010000 250060000 250120000
#  250090000 250110000 250150000 250180000 250070000 250130000 250140000
#  250160000 250020000 250030000 250040000 250050000 250080000 250100000
#  260180000 260290000 260300000 260420000 260430000 260550000 260020000
#  260170000 260190000 260250000 260330000 260360000 260480000 260040000
#  260390000 260520000 260690000 260350000 260260000 260710000 270040000
#  270020000 270070000 270080000 270100000 270120000 270140000 270160000
#  270050000 270060000 270110000 270130000 270150000 270090000 270010000
#  270030000 270170000 280030000 280090000 280220000 280270000 280320000
#  280380000 280410000 280210000 280250000 280330000 280400000 280020000
#  280160000 280190000 280370000 280060000 280130000 280170000 280290000
#  280300000 280340000 280390000 290050000 290060000 290100000 290130000
#  290180000 290250000 290280000 290310000 290330000 290410000 290440000
#  290480000 290010000 290070000 290090000 290140000 290150000 290170000
#  290190000 290210000 290230000 290240000 290260000 290270000 290290000
#  290300000 290320000 290350000 290360000 290380000 290390000 290400000
#  290420000 290430000 290450000 290490000 290500000 290530000 290540000
#  290550000 290560000 290570000 290580000 290600000 290020000 290340000
#  290460000 300280000 300390000 300440000 300870000 301080000 301180000
#  301310000 301930000 300110000 300160000 300260000 300320000 300340000
#  300400000 300480000 300610000 300680000 300850000 300890000 301020000
#  301150000 301240000 301380000 301740000 301890000 300220000 300350000
#  300380000 300530000 300690000 301230000 301330000 301350000 301360000
#  301440000 301690000 301720000 301750000 301820000 301910000 300120000
#  300710000 300730000 301120000 301320000 301410000 301730000 300090000
#  300150000 300210000 300310000 300460000 300540000 300580000 300660000
#  300790000 300900000 300980000 301250000 301270000 301280000 301510000
#  301570000 301680000 301880000 301940000 301980000 302100000 300290000
#  310500000 310380000 310400000 310410000 310520000 310560000 310580000
#  310590000 310790000 310890000 310960000 311010000 311020000 310070000
#  310080000 310130000 310260000 310270000 310320000 310330000 310340000
#  310360000 310420000 310440000 310460000 310480000 310530000 310730000
#  310740000 310850000 310920000 310930000 310190000 310550000 311040000
#  310170000 310300000 310900000 310010000 310510000 310540000 310880000
#  310940000 320100000 320170000 320560000 320050000 320200000 320220000
#  320340000 320390000 320420000 320480000 320010000 320080000 320090000
#  320190000 320230000 320310000 320380000 320400000 320440000 320490000
#  320530000 320550000 320370000 320020000 320060000 320120000 320130000
#  320160000 320240000 320250000 320260000 320290000 320500000 320510000
#  320520000 320540000]
# VALUE COUNTS  10010000     1221
# 230050000     943
# 220140000     857
# 310500000     797
# 20040000      734
#              ...
# 151080000       3
# 202270000       3
# 150920000       3
# 301750000       3
# 200870000       2
# Name: ubica_geo, Length: 926, dtype: int64
#
#
# COLUMNA:  ageb
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  ['000-0']
# VALUE COUNTS  000-0    56680
# Name: ageb, dtype: int64
#
#
# COLUMNA:  tam_loc
# TIPO:  entero
# NUNIQUE:  4
# UNIQUE:  [1 2 3 4]
# VALUE COUNTS  1    24963
# 4    13934
# 3     8941
# 2     8842
# Name: tam_loc, dtype: int64
#
#
# COLUMNA:  est_socio
# TIPO:  entero
# NUNIQUE:  4
# UNIQUE:  [4 3 2 1]
# VALUE COUNTS  2    29380
# 3    11831
# 1    10762
# 4     4707
# Name: est_socio, dtype: int64
#
#
# COLUMNA:  est_dis
# TIPO:  entero
# NUNIQUE:  341
# UNIQUE:  [  8   7   6   1   9  10   2   3  11   4   5  19  18  17  12  13  20  21
#   14  16  15  32  31  30  24  23  25  22  27  26  29  28  39  38  40  37
#   33  35  34  41  36  47  48  49  43  51  50  42  52  44  53  46  45  59
#   58  60  54  55  56  57  68  69  67  70  62  71  61  64  63  65  66  77
#   76  78  72  73  75  74  82  80  81  83  84  79  91  92  90  89  93  85
#   86  87  88 100 101 102  99  94  95 104 103  96 105  98  97 113 112 111
#  114 107 106 109 108 110 119 120 121 115 122 116 123 125 124 126 127 117
#  118 136 135 134 129 128 137 138 139 130 131 133 132 146 145 147 148 149
#  140 151 150 142 152 141 143 144 160 159 161 153 154 162 156 155 163 157
#  158 169 170 171 164 174 173 172 166 175 176 177 165 168 167 183 184 185
#  179 178 187 186 180 182 181 195 194 196 193 189 188 197 199 198 190 192
#  191 206 205 200 208 207 209 202 210 201 212 211 203 204 219 218 220 222
#  221 223 213 224 214 215 226 225 216 217 234 232 233 237 235 236 227 229
#  228 238 239 230 231 245 246 247 244 240 248 241 249 242 243 256 257 258
#  250 251 253 252 254 255 265 264 266 259 260 261 263 262 274 273 275 272
#  267 268 269 271 270 284 282 283 276 277 279 278 285 280 281 292 293 294
#  291 295 296 287 286 288 290 289 302 303 304 297 305 306 298 299 307 308
#  301 300 315 316 314 309 317 318 311 319 310 312 313 328 327 329 326 321
#  331 332 330 320 322 323 333 324 325 340 339 341 334 335 336 338 337]
# VALUE COUNTS  203    874
# 245    852
# 65     815
# 81     791
# 110    690
#       ...
# 212      7
# 52       7
# 126      7
# 114      5
# 177      3
# Name: est_dis, Length: 341, dtype: int64
#
#
# COLUMNA:  upm
# TIPO:  entero
# NUNIQUE:  8092
# UNIQUE:  [   1    2    3 ... 8101 8102 8103]
# VALUE COUNTS  3070    23
# 5128    23
# 1082    23
# 4187    22
# 1837    22
#         ..
# 6111     1
# 448      1
# 2059     1
# 42       1
# 4393     1
# Name: upm, Length: 8092, dtype: int64
#
#
# COLUMNA:  factor
# TIPO:  entero
# NUNIQUE:  1776
# UNIQUE:  [ 221  194  190 ... 1102 1050 1245]
# VALUE COUNTS  184     187
# 133     182
# 203     178
# 122     167
# 157     165
#        ...
# 932       2
# 1677      1
# 2320      1
# 1726      1
# 2076      1
# Name: factor, Length: 1776, dtype: int64

# %% [markdown]
# Graficamos los datos en bruto (raw data)

# %%
msno.bar(df_copy)

# %% [markdown]
# Revisamos la existencia de valores nulos

# %%
df_copy.isnull().any().any()
# Out:
# False

# %% [markdown]
# Reemplazamos los valores & y ' ' por nan

# %%
df_copy.replace(to_replace='&', value=np.nan, inplace=True)

# %%
df_copy.replace(to_replace=' ', value=np.nan, inplace=True)

# %% [markdown]
# Revisamos (de nuevo) la existencia de valores nulos

# %%
df_copy.isnull().any().any()
# Out:
# True

# %% [markdown]
# Graficamos los datos con valores nulos reales

# %%
msno.bar(df_copy)

# %% [markdown]
# Guardamos el dataframe
# Definimos la ruta

# %%
file = "C:/Users/saira/Documents/DIPLOMADO/MODULO IV/PRACTICAS/PRACTICA2/Dataset/vivienda_load.csv"

# %%
df_copy.to_csv(file)

# %% [markdown]
# # Clean

# %% [markdown]
# Reemplazamos el DF

# %%
df_copy.fillna(value=-1, inplace=True)

# %%
threshold = round(df_copy.shape[0]*.75)
threshold
# Out:
# 42510

# %%
l = []
for column in df_copy.columns:
    na_column =  df_copy[column].value_counts().get(-1)
    if(na_column != None):
        print(column, ': ', df_copy.shape[0] - na_column, ' - ', threshold)
        if (df_copy.shape[0] - na_column < threshold):
            print(column, ': ', 'd e l e t e d')
            l.append(column)
# Out:
# tipo_viv :  56566  -  42510
# condominio :  2530  -  42510
# condominio :  d e l e t e d
# elevador :  2530  -  42510
# elevador :  d e l e t e d
# mat_pisos :  56678  -  42510
# antiguedad :  42515  -  42510
# cocina_dor :  53256  -  42510
# dotac_agua :  53152  -  42510
# uso_compar :  54866  -  42510
# sanit_agua :  54866  -  42510
# bano_comp :  54866  -  42510
# bano_excus :  54866  -  42510
# bano_regad :  54866  -  42510
# anio_panel :  44  -  42510
# anio_panel :  d e l e t e d
# panel_ne :  9  -  42510
# panel_ne :  d e l e t e d
# pot_panel :  53  -  42510
# pot_panel :  d e l e t e d
# potencia :  16  -  42510
# potencia :  d e l e t e d
# focos_inca :  56428  -  42510
# focos_ahor :  56428  -  42510
# estufa_chi :  8246  -  42510
# estufa_chi :  d e l e t e d
# estaciona :  24346  -  42510
# estaciona :  d e l e t e d
# comun11 :  2753  -  42510
# comun11 :  d e l e t e d
# comun12 :  2753  -  42510
# comun12 :  d e l e t e d
# comun13 :  2753  -  42510
# comun13 :  d e l e t e d
# comun14 :  2753  -  42510
# comun14 :  d e l e t e d
# comun15 :  2753  -  42510
# comun15 :  d e l e t e d
# comun16 :  2753  -  42510
# comun16 :  d e l e t e d
# comun17 :  2753  -  42510
# comun17 :  d e l e t e d
# pago_renta :  7976  -  42510
# pago_renta :  d e l e t e d
# anio_res :  7976  -  42510
# anio_res :  d e l e t e d
# mes_res :  7976  -  42510
# mes_res :  d e l e t e d
# familiar :  7976  -  42510
# familiar :  d e l e t e d
# tipo_adqui :  36181  -  42510
# tipo_adqui :  d e l e t e d
# financia_1 :  23708  -  42510
# financia_1 :  d e l e t e d
# financia_2 :  242  -  42510
# financia_2 :  d e l e t e d
# financia_3 :  6932  -  42510
# financia_3 :  d e l e t e d
# financia_4 :  1591  -  42510
# financia_4 :  d e l e t e d
# financia_5 :  190  -  42510
# financia_5 :  d e l e t e d
# financia_6 :  359  -  42510
# financia_6 :  d e l e t e d
# financia_7 :  886  -  42510
# financia_7 :  d e l e t e d
# financia_8 :  1444  -  42510
# financia_8 :  d e l e t e d
# num_dueno1 :  36185  -  42510
# num_dueno1 :  d e l e t e d
# hog_dueno1 :  36185  -  42510
# hog_dueno1 :  d e l e t e d
# num_dueno2 :  3882  -  42510
# num_dueno2 :  d e l e t e d
# hog_dueno2 :  3882  -  42510
# hog_dueno2 :  d e l e t e d
# escrituras :  36181  -  42510
# escrituras :  d e l e t e d
# ageb :  0  -  42510
# ageb :  d e l e t e d

# %%
l
# Out:
# ['condominio',
#  'elevador',
#  'anio_panel',
#  'panel_ne',
#  'pot_panel',
#  'potencia',
#  'estufa_chi',
#  'estaciona',
#  'comun11',
#  'comun12',
#  'comun13',
#  'comun14',
#  'comun15',
#  'comun16',
#  'comun17',
#  'pago_renta',
#  'anio_res',
#  'mes_res',
#  'familiar',
#  'tipo_adqui',
#  'financia_1',
#  'financia_2',
#  'financia_3',
#  'financia_4',
#  'financia_5',
#  'financia_6',
#  'financia_7',
#  'financia_8',
#  'num_dueno1',
#  'hog_dueno1',
#  'num_dueno2',
#  'hog_dueno2',
#  'escrituras',
#  'ageb']

# %%
df_copy.drop(labels=l, axis=1, inplace=True)

# %%
df_copy.replace(to_replace=-1, value=np.NaN, inplace=True)

# %%
msno.bar(df_copy)

# %% [markdown]
# Guardamos el dataframe, definimos la ruta

# %%
file = 'C:/Users/saira/Documents/DIPLOMADO/MODULO IV/PRACTICAS/PRACTICA2/Dataset/vivienda_clean.csv'

# %%
df_copy.to_csv(file)

# %%
df_copy.dropna(inplace=True)

# %%
msno.bar(df_copy.dropna)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-0bfccd29cd44> in <module>
# ----> 1 msno.bar(df_copy.dropna)
#
# ~\Anaconda3\envs\Practica2\lib\site-packages\missingno\missingno.py in bar(df, figsize, fontsize, labels, log, color, inline, filter, n, p, sort, ax)
#     224     df = nullity_filter(df, filter=filter, n=n, p=p)
#     225     df = nullity_sort(df, sort=sort, axis='rows')
# --> 226     nullity_counts = len(df) - df.isnull().sum()
#     227
#     228     if ax is None:
#
# TypeError: object of type 'method' has no len()
